# %% [markdown]
# <a href="https://colab.research.google.com/github/YoshnaM/6CS012-Artificial-Intelligence-and-Machine-Learning/blob/main/YoshnaMaharjan_2406791_Worksheet01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Workshop 01**

# %% [markdown]
# # **2.1. Exercise 1**

# %% [markdown]
# 1. Read and display the image.
#
#     • Read the image using the Pillow library and display it.
#
#     • You can also use matplotlib to display the image.

# %%
from PIL import Image
image_colored = Image.open("/content/drive/MyDrive/Artificial_Intelligence_And_Machine_Learning/lenna.png")
display(image_colored)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512>

# %%
import matplotlib.pyplot as plt
plt.imshow(image_colored)
plt.title("Original Image")
plt.axis("off")
plt.show()

# %% [markdown]
# 2. Display only the top left corner of 100x100 pixels.
#
#     • Extract the top-left corner of the image (100x100 pixels) and display it using NumPy and Array Indexing.

# %%
import numpy as np
image_array = np.array(image_colored)
top_left = image_array[0:100, 0:100]
plt.imshow(top_left)
plt.title("Top Left Corner (100x100)")
plt.axis("off")
plt.show()

# %% [markdown]
# 3. Show the three color channels (R, G, B).
#
#     • Separate the image into its three color channels (Red, Green, and Blue) and display them individually, labeling each channel as R, G, and B.{Using NumPy.}

# %%
# Separate color channels
R = image_array[:, :, 0]
G = image_array[:, :, 1]
B = image_array[:, :, 2]

# Display channels with color maps
plt.figure(figsize=(12,4))

plt.subplot(1,3,1)
plt.imshow(R, cmap='Reds')
plt.title("Red Channel (R)")
plt.axis("off")

plt.subplot(1,3,2)
plt.imshow(G, cmap='Greens')
plt.title("Green Channel (G)")
plt.axis("off")

plt.subplot(1,3,3)
plt.imshow(B, cmap='Blues')
plt.title("Blue Channel (B)")
plt.axis("off")

plt.show()

# %% [markdown]
# 4. Modify the top 100 × 100 pixels to a value of 210 and display the resulting image:
#
#     • Modify the pixel values of the top-left 100 × 100 region to have a value of 210 (which is a light gray color), and then display the modified image.

# %%
modified_img = image_array.copy()

modified_img[0:100, 0:100] = 210

plt.imshow(modified_img)
plt.title("Modified Image (Top 100x100 to 210)")
plt.axis("off")
plt.show()

# %% [markdown]
# # **2.2. Exercise 2**

# %% [markdown]
# 1. Load and display a grayscale image.
#
#     • Load a grayscale image using the Pillow library.
#
#     • Display the grayscale image using matplotlib.

# %%
# Load image as grayscale
image = Image.open("/content/drive/MyDrive/Artificial_Intelligence_And_Machine_Learning/cameraman.png").convert("L")

# Convert to numpy array
image_array = np.array(image)

# Display image
plt.imshow(image_array, cmap='gray')
plt.title("Original Grayscale Image")
plt.axis("off")
plt.show()

# %% [markdown]
# 2. Extract and display the middle section of the image (150 pixels).
#
#     • Extract a 150 pixel section from the center of the image using NumPy array slicing.
#
#     • Display this cropped image using matplotlib.

# %%
# Get image dimensions
h, w = image_array.shape

# Calculate center
center_h = h // 2
center_w = w // 2

# Extract 150x150 region
cropped = image_array[center_h-75:center_h+75, center_w-75:center_w+75]

# Display cropped section
plt.imshow(cropped, cmap='gray')
plt.title("Middle 150x150 Pixel")
plt.axis("off")
plt.show()

# %% [markdown]
# 3. Apply a simple threshold to the image (e.g., set all pixel values below 100 to 0).
#
#     • Apply a threshold to the grayscale image: set all pixel values below 100 to 0, and all values above 100 to 255 (creating a binary image).
#
#     • Display the resulting binary image.

# %%
# Apply threshold
binary_image = np.where(image_array < 100, 0, 255)

# Display result
plt.imshow(binary_image, cmap='gray')
plt.title("Threshold Image")
plt.axis("off")
plt.show()

# %% [markdown]
# 4. Rotate the image 90 degrees clockwise and display the result.
#
#     • Rotate the image by 90 degrees clockwise using the Pillow rotate method or by manipulating the image array.
#
#     • Display the rotated image using matplotlib.

# %%
rotated = image.rotate(-90, expand=True)

plt.imshow(rotated, cmap='gray')
plt.title("Rotated Image (90 Degrees Clockwise)")
plt.axis("off")
plt.show()

# %% [markdown]
# 5. Convert the grayscale image to an RGB image.
#
#     • Convert the grayscale image into an RGB image where the grayscale values are replicated across all three channels (R, G, and B).
#
#     • Display the converted RGB image using matplotlib.

# %%
# Replicate grayscale values across 3 channels
rgb_image = np.stack((image_array, image_array, image_array), axis=2)

# Display RGB image
plt.imshow(rgb_image)
plt.title("Converted RGB Image")
plt.axis("off")
plt.show()
